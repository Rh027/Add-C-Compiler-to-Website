# %% [markdown]
# <a href="https://colab.research.google.com/github/Rh027/Add-C-Compiler-to-Website/blob/main/xrp_tf.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from sklearn.metrics import mean_squared_error
from tensorflow.keras.optimizers import Adam
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/!ripple-dat - 0.csv')
df.head()
# Out:
#         timeOpen      timeClose       timeHigh        timeLow  priceOpen  \
# 0  1741521600000  1741607999999  1741525680000  1741587600000   2.323426
# 1  1741435200000  1741521599999  1741438680000  1741477800000   2.381602
# 2  1741348800000  1741435199999  1741349280000  1741428780000   2.601729
# 3  1741262400000  1741348799999  1741299540000  1741265940000   2.500550
# 4  1741176000000  1741262399999  1741214340000  1741198200000   2.455155
#
#    priceHigh  priceLow  priceClose        volume  Date
# 0   2.348783  2.090983    2.134576  6.156172e+09     1
# 1   2.406410  2.309608    2.323439  3.722945e+09     2
# 2   2.610049  2.357011    2.381624  9.796404e+09     3
# 3   2.638425  2.474239    2.601729  6.907451e+09     4
# 4   2.533040  2.418124    2.500509  6.075953e+09     5

# %%
X = df.drop(['timeOpen','timeLow', 'timeClose','timeHigh','timeHigh','priceHigh','volume'],axis=1)
y=df['priceHigh']

# %%
X.head()
# Out:
#    priceOpen  priceLow  priceClose  Date
# 0   2.323426  2.090983    2.134576     1
# 1   2.381602  2.309608    2.323439     2
# 2   2.601729  2.357011    2.381624     3
# 3   2.500550  2.474239    2.601729     4
# 4   2.455155  2.418124    2.500509     5

# %%
y.head()
# Out:
# 0    2.348783
# 1    2.406410
# 2    2.610049
# 3    2.638425
# 4    2.533040
# Name: priceHigh, dtype: float64

# %%
X['MEAN'] = X.mean(axis=1)
X_t = X.drop(['priceOpen','priceLow','priceClose'],axis=1)
X_t.head()
# Out:
#    Date      MEAN
# 0     1  1.887246
# 1     2  2.253662
# 2     3  2.585091
# 3     4  2.894129
# 4     5  3.093447

# %%
Xmean_train, Xmean_test, y_train, y_test = train_test_split(X_t, y, test_size=0.2, random_state=42)

# %%
Xmean_test.iloc[0]
# Out:
# Date    164.00000
# MEAN     41.44066
# Name: 163, dtype: float64

# %%
model = Sequential()
model.add(Dense(units=32, activation='relu', input_dim=len(Xmean_train.shape)))
model.add(Dense(units=64, activation='relu'))
model.add(Dense(units=128, activation='relu'))
model.add(Dense(units=64, activation='relu'))
model.add(Dense(units=32, activation='relu'))
model.add(Dense(units=1))
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.compile(loss='mse', optimizer=Adam(learning_rate=0.01), metrics=['accuracy'])

# %%
model.fit(Xmean_train, y_train, epochs=200, batch_size=32, validation_data=(Xmean_test, y_test))
# Out:
# Epoch 1/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - accuracy: 0.0000e+00 - loss: 221.3297 - val_accuracy: 0.0000e+00 - val_loss: 2.2688
# Epoch 2/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.0000e+00 - loss: 2.3223 - val_accuracy: 0.0000e+00 - val_loss: 2.2029
# Epoch 3/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.0000e+00 - loss: 1.4650 - val_accuracy: 0.0000e+00 - val_loss: 1.5261
# Epoch 4/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.0000e+00 - loss: 1.3960 - val_accuracy: 0.0000e+00 - val_loss: 1.3581
# Epoch 5/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.0000e+00 - loss: 1.9278 - val_accuracy: 0.0000e+00 - val_loss: 1.5854
# Epoch 6/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.0000e+00 - loss: 1.1249 - val_accuracy: 0.0000e+00 - val_loss: 0.4678
# Epoch 7/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.0000e+00 - loss: 0.3367 - val_accuracy: 0.0000e+00 - val_loss: 0.1195
# Epoch 8/200
# ...

# %%
y_hat = model.predict(Xmean_test)
# Out:
# WARNING:tensorflow:5 out of the last 7 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x7fa089bc5760> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/3 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# ...

# %%
y_hat
# Out:
# array([[0.5968352 ],
#        [2.8470616 ],
#        [2.6587348 ],
#        [0.6147529 ],
#        [2.662313  ],
#        [0.5998071 ],
#        [2.4053755 ],
#        [0.60255754],
#        [0.61391735],
#        [0.599666  ],
#        [0.6134057 ],
#        [3.0987165 ],
#        [0.6083318 ],
#        [2.7211795 ],
#        [0.59543395],
#        [0.6029866 ],
#        [0.61295664],
#        [0.6069195 ],
#        [0.61552334],
#        [1.4647397 ],
#        [2.5009165 ],
#        [0.6016185 ],
#        [2.4097624 ],
#        [0.61416626],
#        [0.61534643],
#        [0.60208315],
#        [0.606377  ],
#        [0.5974113 ],
#        [0.5956676 ],
#        [0.6157589 ],
#        [2.6495051 ],
#        [0.9142933 ],
#        [3.212112  ],
#        [0.61556494],
#        [0.5963352 ],
#        [0.6214204 ],
#        [2.5362558 ],
#        [2.7946467 ],
#        [0.6146717 ],
#        [0.59806216],
#        [0.61072326],
#        [0.6148206 ],
#        [2.7229407 ],
# ...

# %%
mean_squared_error(y_test, y_hat)
# Out:
# 0.014925773048728058
